# %% [markdown]
# # **DUSt3R :3D Reconstruction From 2D Images :**

# %%
# uv pip install torch==2.7.0+cu118 torchvision==0.22.0+cu118 --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# 3D Reconstruction/
# │
# ├── data/
# │   └── input/
# │       └── video.mp4
# │
# ├── results/
# │   └── dust3r/
# │       │
# │       ├── exp_01_baseline/
# │       │   ├── dataset/
# │       │   │   ├── frames/
# │       │   │   └── dataset_info.json
# │       │   │
# │       │   ├── results/
# │       │   │   ├── point_cloud.ply
# │       │   │   ├── confidence.ply
# │       │   │   └── metadata.json
# │       │   │
# │       │   └── logs/
# │       │
# │       ├── exp_02_oneref/
# │       │   ├── dataset/
# │       │   │   ├── frames/
# │       │   │   └── dataset_info.json
# │       │   │
# │       │   ├── results/
# │       │   │   ├── point_cloud.ply
# │       │   │   └── metadata.json
# │       │   │
# │       │   └── logs/
# │       │
# │       ├── exp_03_more_frames/
# │       │   ├── dataset/
# │       │   ├── results/
# │       │   └── logs/
# │       │
# │       └── ...
# │
# ├── src/
# │   └── dust3r/
# │       ├── frame_extractor.py
# │       ├── reconstruction.py
# │       ├── visualization.py
# │       └── pipeline.py
# │
# └── notebook/
#     └── dust3r/
#         ├── 01_data_processing.ipynb
#         ├── 02_two_image_test.ipynb
#         ├── 03_global_alignment.ipynb
#         └── 04_experiments.ipynb

# %% [markdown]
# ## **Dust3R dataset Preprocessing :**

# %%
experiment='06'
num_frame=40

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()

while PROJECT_ROOT.name != "3D Reconstruction":
    PROJECT_ROOT = PROJECT_ROOT.parent

# Our project code
sys.path.insert(0, str(PROJECT_ROOT))

# Official DUSt3R repository
sys.path.insert(0, str(PROJECT_ROOT / "dust3r"))

print("Project root:", PROJECT_ROOT)
print("Official DUSt3R:", PROJECT_ROOT / "dust3r")
# Out:
# Project root: d:\3D Reconstruction
# Official DUSt3R: d:\3D Reconstruction\dust3r

# %%
from src.dust3r.data_preprocessing import extract_uniform_frames

# %%
Path.cwd().parent
# Out:
# WindowsPath('d:/3D Reconstruction/notebook')

# %%
video_path = PROJECT_ROOT / "video"/ "video.mp4"

video_path
# Out:
# WindowsPath('d:/3D Reconstruction/video/video.mp4')

# %%
output_dir = (
        PROJECT_ROOT
        /"src"
        / "results"
        / "dust3r"
        / f"exp_{experiment}_baseline"
        / "dataset"
        / "frames"
    )

extract_uniform_frames(
        video_path=video_path,
        output_dir=output_dir,
        num_frames=num_frame,
    )
# Out:
# Video: d:\3D Reconstruction\video\video.mp4
# Original frames: 397
# Original FPS: 30.00
# Selected frames: 40
# Saved to: d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames
# Metadata: d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\dataset_info.json

# %%
frames=sorted(output_dir.glob("*.jpg"))

print(f'Number of Frames : {len(frames)}')

for frame in frames:
    print(frame.name)
# Out:
# Number of Frames : 40
# frame_0000.jpg
# frame_0001.jpg
# frame_0002.jpg
# frame_0003.jpg
# frame_0004.jpg
# frame_0005.jpg
# frame_0006.jpg
# frame_0007.jpg
# frame_0008.jpg
# frame_0009.jpg
# frame_0010.jpg
# frame_0011.jpg
# frame_0012.jpg
# frame_0013.jpg
# frame_0014.jpg
# frame_0015.jpg
# frame_0016.jpg
# frame_0017.jpg
# frame_0018.jpg
# frame_0019.jpg
# frame_0020.jpg
# frame_0021.jpg
# frame_0022.jpg
# frame_0023.jpg
# frame_0024.jpg
# frame_0025.jpg
# frame_0026.jpg
# frame_0027.jpg
# frame_0028.jpg
# frame_0029.jpg
# frame_0030.jpg
# frame_0031.jpg
# frame_0032.jpg
# frame_0033.jpg
# frame_0034.jpg
# frame_0035.jpg
# frame_0036.jpg
# frame_0037.jpg
# frame_0038.jpg
# frame_0039.jpg

# %%
import matplotlib.pyplot as plt
from PIL import Image


fig,axes=plt.subplots(4,5,figsize=(15,10))

for ax ,frame_path in zip(axes.flat,frames):
    image=Image.open(frame_path)

    ax.imshow(image)
    ax.set_title(frame_path.stem)
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
from PIL import Image

for frame_path in frames[:3]:
    image = Image.open(frame_path)

    print(
        frame_path.name,
        "size =", image.size,
        "mode =", image.mode
    )
# Out:
# frame_0000.jpg size = (408, 720) mode = RGB
# frame_0001.jpg size = (408, 720) mode = RGB
# frame_0002.jpg size = (408, 720) mode = RGB

# %% [markdown]
# ## **Working with Dust3R Model :**

# %%
# !git clone --recursive https://github.com/naver/dust3r

# %%
# # * downloading the Model :

from src.dust3r.model_manager import get_checkpoint

CHECKPOINT_DIR = (
    PROJECT_ROOT
    / "dust3r"
    / "checkpoints"
)

CHECKPOINT_DIR
# Out:
# WindowsPath('d:/3D Reconstruction/dust3r/checkpoints')

# %%
checkpoint_path = get_checkpoint(
    model_name="512_dpt",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth

# %%
checkpoint_path = get_checkpoint(
    model_name="512_linear",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_linear.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_linear.pth

# %%
checkpoint_path = get_checkpoint(
    model_name="224_linear",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_224_linear.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_224_linear.pth

# %% [markdown]
# ## **Loading the Model + Inference Test :**

# %%
import dust3r

print(dust3r.__file__)
# Out:
# d:\3D Reconstruction\dust3r\dust3r\__init__.py

# %%
from pathlib import Path

from src.dust3r.reconstruction import reconstruct



frames_dir = (
    PROJECT_ROOT
    /"src"
    / "results"
    / "dust3r"
    / f"exp_{experiment}_baseline"
    / "dataset"
    / "frames"
)

checkpoint_path = (
    PROJECT_ROOT
    / "dust3r"
    / "checkpoints"
    / "DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth"
)

output_dir = (
    PROJECT_ROOT
    /"src"
    / "results"
    / "dust3r"
    / f"exp_{experiment}_baseline"
    / "results"
)
# Out:
# d:\3D Reconstruction\dust3r\dust3r\cloud_opt\base_opt.py:275: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)

# %%
print(frames_dir)
print(frames_dir.exists())
print(list(frames_dir.glob("*"))[:10])
# Out:
# d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames
# True
# [WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0000.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0001.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0002.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0003.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0004.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0005.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0006.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0007.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0008.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/dataset/frames/frame_0009.jpg')]

# %%
reconstruct(
    frames_dir=frames_dir,
    checkpoint_path=checkpoint_path,
    output_dir=output_dir,
    scene_graph="swin-6",
    niter=500
)
# Out:
# Device: cuda
# Frames: d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames
# Checkpoint: d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# Warning, cannot find cuda-compiled version of RoPE2D, using a slow pytorch version instead
#
# Loading DUSt3R model...
# ... loading model from d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# instantiating : AsymmetricCroCo3DStereo(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100', patch_embed_cls='PatchEmbedDust3R', img_size=(512, 512), head_type='dpt', output_mode='pts3d', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), landscape_only=False)
# <All keys matched successfully>
# Model loaded.
#
# Loading 40 images...
# >> Loading a list of 40 images
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0000.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0001.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0002.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0003.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0004.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0005.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0006.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0007.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0008.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0009.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0010.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0011.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0012.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0013.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0014.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0015.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0016.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0017.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0018.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0019.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0020.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0021.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0022.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0023.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0024.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0025.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0026.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0027.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0028.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0029.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0030.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0031.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0032.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0033.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0034.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0035.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0036.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0037.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0038.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\dataset\frames\frame_0039.jpg with resolution 408x720 --> 288x512
#  (Found 40 images)
# Images loaded.
#
# Creating image pairs...
# Number of pairs: 480
#
# Running DUSt3R inference...
# >> Inference with model on 480 image pairs
#   0%|          | 0/480 [00:00<?, ?it/s]d:\3D Reconstruction\dust3r\dust3r\inference.py:44: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=bool(use_amp)):
# d:\3D Reconstruction\dust3r\dust3r\model.py:264: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# d:\3D Reconstruction\dust3r\dust3r\inference.py:48: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 100%|██████████| 480/480 [02:16<00:00,  3.52it/s]
# Inference completed.
#
# Running global alignment...
#  init edge (34*,33*) score=np.float64(218.811767578125)
#  init edge (34,32*) score=np.float64(188.6794891357422)
#  init edge (34,36*) score=np.float64(164.55203247070312)
#  init edge (35*,33) score=np.float64(164.3236541748047)
#  init edge (31*,34) score=np.float64(128.47622680664062)
#  init edge (33,30*) score=np.float64(107.94963073730469)
#  init edge (36,38*) score=np.float64(102.56714630126953)
#  init edge (37*,36) score=np.float64(101.4380874633789)
#  init edge (32,29*) score=np.float64(96.91087341308594)
#  init edge (32,28*) score=np.float64(88.49844360351562)
#  init edge (29,27*) score=np.float64(85.94749450683594)
#  init edge (35,39*) score=np.float64(72.41162109375)
#  init edge (26*,28) score=np.float64(65.95914459228516)
#  init edge (25*,27) score=np.float64(37.35128402709961)
#  init edge (25,22*) score=np.float64(37.15843200683594)
#  init edge (21*,22) score=np.float64(67.0921630859375)
#  init edge (21,18*) score=np.float64(62.120361328125)
#  init edge (21,24*) score=np.float64(45.046836853027344)
#  init edge (21,23*) score=np.float64(44.12298583984375)
#  init edge (21,19*) score=np.float64(77.1969223022461)
#  init edge (19,14*) score=np.float64(63.37186050415039)
#  init edge (20*,19) score=np.float64(59.2908935546875)
#  init edge (19,17*) score=np.float64(56.72199630737305)
#  init edge (19,16*) score=np.float64(56.64885330200195)
#  init edge (9*,14) score=np.float64(100.73556518554688)
#  init edge (9,13*) score=np.float64(99.65489196777344)
#  init edge (9,15*) score=np.float64(60.79885482788086)
#  init edge (9,6*) score=np.float64(165.21153259277344)
#  init edge (9,4*) score=np.float64(144.9735565185547)
#  init edge (3*,6) score=np.float64(139.8883514404297)
#  init edge (5*,9) score=np.float64(136.55697631835938)
#  init edge (10*,6) score=np.float64(129.48818969726562)
#  init edge (7*,9) score=np.float64(129.0517120361328)
#  init edge (8*,6) score=np.float64(123.24681091308594)
#  init edge (2*,6) score=np.float64(106.83099365234375)
#  init edge (7,11*) score=np.float64(106.65170288085938)
#  init edge (6,1*) score=np.float64(102.24836730957031)
#  init edge (6,0*) score=np.float64(93.01131439208984)
#  init edge (7,12*) score=np.float64(81.1522445678711)
#  init loss = 0.015093383379280567
# Global alignement - optimizing for:
# ['pw_poses', 'im_depthmaps', 'im_poses', 'im_focals']
# 100%|██████████| 500/500 [1:26:09<00:00, 10.34s/it, lr=1.09869e-06 loss=0.00707456]
# Global alignment completed.
# Final loss: 0.007074558641761541
#
# Extracting point cloud...
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Point count: 5634757
#
# Point cloud saved:
# d:\3D Reconstruction\src\results\dust3r\exp_06_baseline\results\point_cloud.ply
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/results/point_cloud.ply')

# %%
output_dir
# Out:
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/results')

# %%
point_cloud=output_dir/"point_cloud.ply"
point_cloud
# Out:
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_06_baseline/results/point_cloud.ply')

# %%
import open3d as o3d

point_cloud=output_dir/"point_cloud.ply"


dense_pcd = o3d.io.read_point_cloud(
    point_cloud
)


print(dense_pcd)
print("Dense points:", len(dense_pcd.points))
# Out:
# PointCloud with 5634757 points.
# Dense points: 5634757

# %%
o3d.visualization.draw_geometries([dense_pcd])
