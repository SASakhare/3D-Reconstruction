# %% [markdown]
# # **DUSt3R :3D Reconstruction From 2D Images :**

# %%
# uv pip install torch==2.7.0+cu118 torchvision==0.22.0+cu118 --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# 3D Reconstruction/
# │
# ├── data/
# │   └── input/
# │       └── video.mp4
# │
# ├── results/
# │   └── dust3r/
# │       │
# │       ├── exp_01_baseline/
# │       │   ├── dataset/
# │       │   │   ├── frames/
# │       │   │   └── dataset_info.json
# │       │   │
# │       │   ├── results/
# │       │   │   ├── point_cloud.ply
# │       │   │   ├── confidence.ply
# │       │   │   └── metadata.json
# │       │   │
# │       │   └── logs/
# │       │
# │       ├── exp_02_oneref/
# │       │   ├── dataset/
# │       │   │   ├── frames/
# │       │   │   └── dataset_info.json
# │       │   │
# │       │   ├── results/
# │       │   │   ├── point_cloud.ply
# │       │   │   └── metadata.json
# │       │   │
# │       │   └── logs/
# │       │
# │       ├── exp_03_more_frames/
# │       │   ├── dataset/
# │       │   ├── results/
# │       │   └── logs/
# │       │
# │       └── ...
# │
# ├── src/
# │   └── dust3r/
# │       ├── frame_extractor.py
# │       ├── reconstruction.py
# │       ├── visualization.py
# │       └── pipeline.py
# │
# └── notebook/
#     └── dust3r/
#         ├── 01_data_processing.ipynb
#         ├── 02_two_image_test.ipynb
#         ├── 03_global_alignment.ipynb
#         └── 04_experiments.ipynb

# %% [markdown]
# ## **Dust3R dataset Preprocessing :**

# %%
experiment='02'

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()

while PROJECT_ROOT.name != "3D Reconstruction":
    PROJECT_ROOT = PROJECT_ROOT.parent

# Our project code
sys.path.insert(0, str(PROJECT_ROOT))

# Official DUSt3R repository
sys.path.insert(0, str(PROJECT_ROOT / "dust3r"))

print("Project root:", PROJECT_ROOT)
print("Official DUSt3R:", PROJECT_ROOT / "dust3r")
# Out:
# Project root: d:\3D Reconstruction
# Official DUSt3R: d:\3D Reconstruction\dust3r

# %%
from src.dust3r.data_preprocessing import extract_uniform_frames

# %%
Path.cwd().parent
# Out:
# WindowsPath('d:/3D Reconstruction/notebook')

# %%
video_path = PROJECT_ROOT / "video"/ "video.mp4"

video_path
# Out:
# WindowsPath('d:/3D Reconstruction/video/video.mp4')

# %%
output_dir = (
        PROJECT_ROOT
        /"src"
        / "results"
        / "dust3r"
        / f"exp_{experiment}_baseline"
        / "dataset"
        / "frames"
    )

extract_uniform_frames(
        video_path=video_path,
        output_dir=output_dir,
        num_frames=100,
    )
# Out:
# Video: d:\3D Reconstruction\video\video.mp4
# Original frames: 397
# Original FPS: 30.00
# Selected frames: 100
# Saved to: d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames
# Metadata: d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\dataset_info.json

# %%
frames=sorted(output_dir.glob("*.jpg"))

print(f'Number of Frames : {len(frames)}')

for frame in frames:
    print(frame.name)
# Out:
# Number of Frames : 100
# frame_0000.jpg
# frame_0001.jpg
# frame_0002.jpg
# frame_0003.jpg
# frame_0004.jpg
# frame_0005.jpg
# frame_0006.jpg
# frame_0007.jpg
# frame_0008.jpg
# frame_0009.jpg
# frame_0010.jpg
# frame_0011.jpg
# frame_0012.jpg
# frame_0013.jpg
# frame_0014.jpg
# frame_0015.jpg
# frame_0016.jpg
# frame_0017.jpg
# frame_0018.jpg
# frame_0019.jpg
# frame_0020.jpg
# frame_0021.jpg
# frame_0022.jpg
# frame_0023.jpg
# frame_0024.jpg
# frame_0025.jpg
# frame_0026.jpg
# frame_0027.jpg
# frame_0028.jpg
# frame_0029.jpg
# frame_0030.jpg
# frame_0031.jpg
# frame_0032.jpg
# frame_0033.jpg
# frame_0034.jpg
# frame_0035.jpg
# frame_0036.jpg
# frame_0037.jpg
# frame_0038.jpg
# frame_0039.jpg
# frame_0040.jpg
# frame_0041.jpg
# frame_0042.jpg
# frame_0043.jpg
# frame_0044.jpg
# frame_0045.jpg
# frame_0046.jpg
# frame_0047.jpg
# frame_0048.jpg
# frame_0049.jpg
# frame_0050.jpg
# frame_0051.jpg
# frame_0052.jpg
# frame_0053.jpg
# frame_0054.jpg
# frame_0055.jpg
# frame_0056.jpg
# frame_0057.jpg
# frame_0058.jpg
# frame_0059.jpg
# frame_0060.jpg
# frame_0061.jpg
# frame_0062.jpg
# frame_0063.jpg
# frame_0064.jpg
# frame_0065.jpg
# frame_0066.jpg
# frame_0067.jpg
# frame_0068.jpg
# frame_0069.jpg
# frame_0070.jpg
# frame_0071.jpg
# frame_0072.jpg
# frame_0073.jpg
# frame_0074.jpg
# frame_0075.jpg
# frame_0076.jpg
# frame_0077.jpg
# frame_0078.jpg
# frame_0079.jpg
# frame_0080.jpg
# frame_0081.jpg
# frame_0082.jpg
# frame_0083.jpg
# frame_0084.jpg
# frame_0085.jpg
# frame_0086.jpg
# frame_0087.jpg
# frame_0088.jpg
# frame_0089.jpg
# frame_0090.jpg
# frame_0091.jpg
# frame_0092.jpg
# frame_0093.jpg
# frame_0094.jpg
# frame_0095.jpg
# frame_0096.jpg
# frame_0097.jpg
# frame_0098.jpg
# frame_0099.jpg

# %%
import matplotlib.pyplot as plt
from PIL import Image


fig,axes=plt.subplots(4,5,figsize=(15,10))

for ax ,frame_path in zip(axes.flat,frames):
    image=Image.open(frame_path)

    ax.imshow(image)
    ax.set_title(frame_path.stem)
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
from PIL import Image

for frame_path in frames[:3]:
    image = Image.open(frame_path)

    print(
        frame_path.name,
        "size =", image.size,
        "mode =", image.mode
    )
# Out:
# frame_0000.jpg size = (408, 720) mode = RGB
# frame_0001.jpg size = (408, 720) mode = RGB
# frame_0002.jpg size = (408, 720) mode = RGB

# %% [markdown]
# ## **Working with Dust3R Model :**

# %%
# !git clone --recursive https://github.com/naver/dust3r

# %%
# # * downloading the Model :

from src.dust3r.model_manager import get_checkpoint

CHECKPOINT_DIR = (
    PROJECT_ROOT
    / "dust3r"
    / "checkpoints"
)

CHECKPOINT_DIR
# Out:
# WindowsPath('d:/3D Reconstruction/dust3r/checkpoints')

# %%
checkpoint_path = get_checkpoint(
    model_name="512_dpt",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth

# %%
checkpoint_path = get_checkpoint(
    model_name="512_linear",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_linear.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_linear.pth

# %%
checkpoint_path = get_checkpoint(
    model_name="224_linear",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_224_linear.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_224_linear.pth

# %% [markdown]
# ## **Loading the Model + Inference Test :**

# %%
import dust3r

print(dust3r.__file__)
# Out:
# d:\3D Reconstruction\dust3r\dust3r\__init__.py

# %%
from pathlib import Path

from src.dust3r.reconstruction import reconstruct



frames_dir = (
    PROJECT_ROOT
    /"src"
    / "results"
    / "dust3r"
    / f"exp_{experiment}_baseline"
    / "dataset"
    / "frames"
)

checkpoint_path = (
    PROJECT_ROOT
    / "dust3r"
    / "checkpoints"
    / "DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth"
)

output_dir = (
    PROJECT_ROOT
    /"src"
    / "results"
    / "dust3r"
    / f"exp_{experiment}_baseline"
    / "results"
)
# Out:
# d:\3D Reconstruction\dust3r\dust3r\cloud_opt\base_opt.py:275: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)

# %%
print(frames_dir)
print(frames_dir.exists())
print(list(frames_dir.glob("*"))[:10])
# Out:
# d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames
# True
# [WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0000.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0001.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0002.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0003.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0004.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0005.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0006.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0007.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0008.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/dataset/frames/frame_0009.jpg')]

# %%
reconstruct(
    frames_dir=frames_dir,
    checkpoint_path=checkpoint_path,
    output_dir=output_dir,
)
# Out:
# Device: cuda
# Frames: d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames
# Checkpoint: d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# Warning, cannot find cuda-compiled version of RoPE2D, using a slow pytorch version instead
#
# Loading DUSt3R model...
# ... loading model from d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# instantiating : AsymmetricCroCo3DStereo(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100', patch_embed_cls='PatchEmbedDust3R', img_size=(512, 512), head_type='dpt', output_mode='pts3d', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), landscape_only=False)
# <All keys matched successfully>
# Model loaded.
#
# Loading 100 images...
# >> Loading a list of 100 images
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0000.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0001.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0002.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0003.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0004.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0005.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0006.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0007.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0008.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0009.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0010.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0011.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0012.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0013.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0014.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0015.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0016.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0017.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0018.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0019.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0020.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0021.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0022.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0023.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0024.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0025.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0026.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0027.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0028.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0029.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0030.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0031.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0032.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0033.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0034.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0035.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0036.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0037.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0038.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0039.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0040.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0041.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0042.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0043.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0044.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0045.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0046.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0047.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0048.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0049.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0050.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0051.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0052.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0053.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0054.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0055.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0056.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0057.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0058.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0059.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0060.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0061.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0062.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0063.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0064.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0065.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0066.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0067.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0068.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0069.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0070.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0071.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0072.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0073.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0074.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0075.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0076.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0077.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0078.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0079.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0080.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0081.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0082.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0083.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0084.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0085.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0086.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0087.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0088.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0089.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0090.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0091.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0092.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0093.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0094.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0095.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0096.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0097.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0098.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\dataset\frames\frame_0099.jpg with resolution 408x720 --> 288x512
#  (Found 100 images)
# Images loaded.
#
# Creating image pairs...
# Number of pairs: 400
#
# Running DUSt3R inference...
# >> Inference with model on 400 image pairs
#   0%|          | 0/400 [00:00<?, ?it/s]d:\3D Reconstruction\dust3r\dust3r\inference.py:44: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=bool(use_amp)):
# d:\3D Reconstruction\dust3r\dust3r\model.py:264: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# d:\3D Reconstruction\dust3r\dust3r\inference.py:48: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 100%|██████████| 400/400 [01:53<00:00,  3.51it/s]
# Inference completed.
#
# Running global alignment...
#  init edge (85*,86*) score=np.float64(214.2471923828125)
#  init edge (83*,85) score=np.float64(208.2825164794922)
#  init edge (84*,86) score=np.float64(206.74806213378906)
#  init edge (85,87*) score=np.float64(203.7620391845703)
#  init edge (82*,84) score=np.float64(176.6240692138672)
#  init edge (81*,83) score=np.float64(162.34573364257812)
#  init edge (86,88*) score=np.float64(156.75888061523438)
#  init edge (88,90*) score=np.float64(124.1480941772461)
#  init edge (80*,82) score=np.float64(120.74202728271484)
#  init edge (88,89*) score=np.float64(103.19056701660156)
#  init edge (79*,81) score=np.float64(99.0428237915039)
#  init edge (90,92*) score=np.float64(95.85922241210938)
#  init edge (94*,92) score=np.float64(82.1583480834961)
#  init edge (77*,79) score=np.float64(71.25120544433594)
#  init edge (77,76*) score=np.float64(64.29324340820312)
#  init edge (78*,80) score=np.float64(63.452308654785156)
#  init edge (77,75*) score=np.float64(62.164981842041016)
#  init edge (75,73*) score=np.float64(60.334007263183594)
#  init edge (75,74*) score=np.float64(51.01664352416992)
#  init edge (96*,94) score=np.float64(48.508514404296875)
#  init edge (89,91*) score=np.float64(121.92166137695312)
#  init edge (93*,91) score=np.float64(90.49785614013672)
#  init edge (73,71*) score=np.float64(73.41976928710938)
#  init edge (95*,93) score=np.float64(65.6573486328125)
#  init edge (71,69*) score=np.float64(62.33467483520508)
#  init edge (69,67*) score=np.float64(52.791080474853516)
#  init edge (70*,69) score=np.float64(50.73849105834961)
#  init edge (97*,95) score=np.float64(49.53547668457031)
#  init edge (98*,97) score=np.float64(44.90991973876953)
#  init edge (65*,67) score=np.float64(42.25368118286133)
#  init edge (98,99*) score=np.float64(27.313512802124023)
#  init edge (63*,65) score=np.float64(19.7592830657959)
#  init edge (72*,70) score=np.float64(67.59550476074219)
#  init edge (70,68*) score=np.float64(64.44330596923828)
#  init edge (68,66*) score=np.float64(49.505794525146484)
#  init edge (66,64*) score=np.float64(27.977176666259766)
#  init edge (64,62*) score=np.float64(15.399456024169922)
#  init edge (60*,62) score=np.float64(21.70464515686035)
#  init edge (58*,60) score=np.float64(34.51598358154297)
#  init edge (60,61*) score=np.float64(26.94706916809082)
#  init edge (56*,58) score=np.float64(37.02199172973633)
#  init edge (55*,56) score=np.float64(50.58821487426758)
#  init edge (55,57*) score=np.float64(44.080116271972656)
#  init edge (57,59*) score=np.float64(29.673919677734375)
#  init edge (53*,55) score=np.float64(70.76155853271484)
#  init edge (53,54*) score=np.float64(64.00741577148438)
#  init edge (53,51*) score=np.float64(74.64299011230469)
#  init edge (51,50*) score=np.float64(67.10530090332031)
#  init edge (50,49*) score=np.float64(63.43427658081055)
#  init edge (52*,50) score=np.float64(58.110389709472656)
#  init edge (49,47*) score=np.float64(53.048362731933594)
#  init edge (50,48*) score=np.float64(68.35467529296875)
#  init edge (46*,48) score=np.float64(55.82626724243164)
#  init edge (46,45*) score=np.float64(37.871829986572266)
#  init edge (46,44*) score=np.float64(33.92481231689453)
#  init edge (45,43*) score=np.float64(23.08077049255371)
#  init edge (42*,43) score=np.float64(17.50702667236328)
#  init edge (40*,42) score=np.float64(18.013206481933594)
#  init edge (40,38*) score=np.float64(32.81047821044922)
#  init edge (38,36*) score=np.float64(31.266714096069336)
#  init edge (39*,38) score=np.float64(28.17289924621582)
#  init edge (39,41*) score=np.float64(24.57996940612793)
#  init edge (36,34*) score=np.float64(42.75449752807617)
#  init edge (36,35*) score=np.float64(36.81095504760742)
#  init edge (37*,35) score=np.float64(34.03376770019531)
#  init edge (35,33*) score=np.float64(39.44272994995117)
#  init edge (33,32*) score=np.float64(29.273754119873047)
#  init edge (32,30*) score=np.float64(30.2020320892334)
#  init edge (30,29*) score=np.float64(56.24546813964844)
#  init edge (31*,29) score=np.float64(36.224788665771484)
#  init edge (29,27*) score=np.float64(60.446258544921875)
#  init edge (27,25*) score=np.float64(81.09559631347656)
#  init edge (25,23*) score=np.float64(93.2953109741211)
#  init edge (25,24*) score=np.float64(91.76139068603516)
#  init edge (24,22*) score=np.float64(102.37158203125)
#  init edge (22,20*) score=np.float64(97.43681335449219)
#  init edge (24,26*) score=np.float64(93.40795135498047)
#  init edge (20,18*) score=np.float64(89.5201416015625)
#  init edge (21*,20) score=np.float64(78.34028625488281)
#  init edge (28*,26) score=np.float64(62.0072135925293)
#  init edge (18,16*) score=np.float64(106.34052276611328)
#  init edge (21,19*) score=np.float64(80.29798889160156)
#  init edge (16,15*) score=np.float64(80.25379180908203)
#  init edge (16,14*) score=np.float64(108.8097152709961)
#  init edge (15,13*) score=np.float64(94.1992416381836)
#  init edge (15,17*) score=np.float64(87.99443054199219)
#  init edge (14,12*) score=np.float64(75.445556640625)
#  init edge (13,11*) score=np.float64(59.21049118041992)
#  init edge (12,10*) score=np.float64(56.06926727294922)
#  init edge (11,9*) score=np.float64(49.65205764770508)
#  init edge (8*,10) score=np.float64(38.22572708129883)
#  init edge (7*,9) score=np.float64(49.92430877685547)
#  init edge (5*,7) score=np.float64(32.078426361083984)
#  init edge (5,6*) score=np.float64(31.497568130493164)
#  init edge (4*,6) score=np.float64(30.29775047302246)
#  init edge (4,3*) score=np.float64(27.87217903137207)
#  init edge (4,2*) score=np.float64(26.779001235961914)
#  init edge (1*,3) score=np.float64(15.331814765930176)
#  init edge (0*,1) score=np.float64(17.670190811157227)
#  init loss = 0.01747104898095131
# Global alignement - optimizing for:
# ['pw_poses', 'im_depthmaps', 'im_poses', 'im_focals']
# 100%|██████████| 300/300 [54:38<00:00, 10.93s/it, lr=1.27413e-06 loss=0.00515403]
# Global alignment completed.
# Final loss: 0.005154033191502094
#
# Extracting point cloud...
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Point count: 13778889
#
# Point cloud saved:
# d:\3D Reconstruction\src\results\dust3r\exp_02_baseline\results\point_cloud.ply
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/results/point_cloud.ply')

# %%
output_dir
# Out:
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/results')

# %%
point_cloud=output_dir/"point_cloud.ply"
point_cloud
# Out:
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_02_baseline/results/point_cloud.ply')

# %%
import open3d as o3d

point_cloud=output_dir/"point_cloud.ply"


dense_pcd = o3d.io.read_point_cloud(
    point_cloud
)


print(dense_pcd)
print("Dense points:", len(dense_pcd.points))
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# PointCloud with 13778889 points.
# Dense points: 13778889

# %%
o3d.visualization.draw_geometries([dense_pcd])
