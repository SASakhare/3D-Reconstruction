# %% [markdown]
# # **DUSt3R :3D Reconstruction From 2D Images :**

# %%
# uv pip install torch==2.7.0+cu118 torchvision==0.22.0+cu118 --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# 3D Reconstruction/
# │
# ├── data/
# │   └── input/
# │       └── video.mp4
# │
# ├── results/
# │   └── dust3r/
# │       │
# │       ├── exp_01_baseline/
# │       │   ├── dataset/
# │       │   │   ├── frames/
# │       │   │   └── dataset_info.json
# │       │   │
# │       │   ├── results/
# │       │   │   ├── point_cloud.ply
# │       │   │   ├── confidence.ply
# │       │   │   └── metadata.json
# │       │   │
# │       │   └── logs/
# │       │
# │       ├── exp_02_oneref/
# │       │   ├── dataset/
# │       │   │   ├── frames/
# │       │   │   └── dataset_info.json
# │       │   │
# │       │   ├── results/
# │       │   │   ├── point_cloud.ply
# │       │   │   └── metadata.json
# │       │   │
# │       │   └── logs/
# │       │
# │       ├── exp_03_more_frames/
# │       │   ├── dataset/
# │       │   ├── results/
# │       │   └── logs/
# │       │
# │       └── ...
# │
# ├── src/
# │   └── dust3r/
# │       ├── frame_extractor.py
# │       ├── reconstruction.py
# │       ├── visualization.py
# │       └── pipeline.py
# │
# └── notebook/
#     └── dust3r/
#         ├── 01_data_processing.ipynb
#         ├── 02_two_image_test.ipynb
#         ├── 03_global_alignment.ipynb
#         └── 04_experiments.ipynb

# %% [markdown]
# ## **Dust3R dataset Preprocessing :**

# %%
experiment='04'
num_frame=120

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()

while PROJECT_ROOT.name != "3D Reconstruction":
    PROJECT_ROOT = PROJECT_ROOT.parent

# Our project code
sys.path.insert(0, str(PROJECT_ROOT))

# Official DUSt3R repository
sys.path.insert(0, str(PROJECT_ROOT / "dust3r"))

print("Project root:", PROJECT_ROOT)
print("Official DUSt3R:", PROJECT_ROOT / "dust3r")
# Out:
# Project root: d:\3D Reconstruction
# Official DUSt3R: d:\3D Reconstruction\dust3r

# %%
from src.dust3r.data_preprocessing import extract_uniform_frames

# %%
Path.cwd().parent
# Out:
# WindowsPath('d:/3D Reconstruction/notebook')

# %%
video_path = PROJECT_ROOT / "video"/ "video.mp4"

video_path
# Out:
# WindowsPath('d:/3D Reconstruction/video/video.mp4')

# %%
output_dir = (
        PROJECT_ROOT
        /"src"
        / "results"
        / "dust3r"
        / f"exp_{experiment}_baseline"
        / "dataset"
        / "frames"
    )

extract_uniform_frames(
        video_path=video_path,
        output_dir=output_dir,
        num_frames=num_frame,
    )
# Out:
# Video: d:\3D Reconstruction\video\video.mp4
# Original frames: 397
# Original FPS: 30.00
# Selected frames: 120
# Saved to: d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames
# Metadata: d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\dataset_info.json

# %%
frames=sorted(output_dir.glob("*.jpg"))

print(f'Number of Frames : {len(frames)}')

for frame in frames:
    print(frame.name)
# Out:
# Number of Frames : 120
# frame_0000.jpg
# frame_0001.jpg
# frame_0002.jpg
# frame_0003.jpg
# frame_0004.jpg
# frame_0005.jpg
# frame_0006.jpg
# frame_0007.jpg
# frame_0008.jpg
# frame_0009.jpg
# frame_0010.jpg
# frame_0011.jpg
# frame_0012.jpg
# frame_0013.jpg
# frame_0014.jpg
# frame_0015.jpg
# frame_0016.jpg
# frame_0017.jpg
# frame_0018.jpg
# frame_0019.jpg
# frame_0020.jpg
# frame_0021.jpg
# frame_0022.jpg
# frame_0023.jpg
# frame_0024.jpg
# frame_0025.jpg
# frame_0026.jpg
# frame_0027.jpg
# frame_0028.jpg
# frame_0029.jpg
# frame_0030.jpg
# frame_0031.jpg
# frame_0032.jpg
# frame_0033.jpg
# frame_0034.jpg
# frame_0035.jpg
# frame_0036.jpg
# frame_0037.jpg
# frame_0038.jpg
# frame_0039.jpg
# frame_0040.jpg
# frame_0041.jpg
# frame_0042.jpg
# frame_0043.jpg
# frame_0044.jpg
# frame_0045.jpg
# frame_0046.jpg
# frame_0047.jpg
# frame_0048.jpg
# frame_0049.jpg
# frame_0050.jpg
# frame_0051.jpg
# frame_0052.jpg
# frame_0053.jpg
# frame_0054.jpg
# frame_0055.jpg
# frame_0056.jpg
# frame_0057.jpg
# frame_0058.jpg
# frame_0059.jpg
# frame_0060.jpg
# frame_0061.jpg
# frame_0062.jpg
# frame_0063.jpg
# frame_0064.jpg
# frame_0065.jpg
# frame_0066.jpg
# frame_0067.jpg
# frame_0068.jpg
# frame_0069.jpg
# frame_0070.jpg
# frame_0071.jpg
# frame_0072.jpg
# frame_0073.jpg
# frame_0074.jpg
# frame_0075.jpg
# frame_0076.jpg
# frame_0077.jpg
# frame_0078.jpg
# frame_0079.jpg
# frame_0080.jpg
# frame_0081.jpg
# frame_0082.jpg
# frame_0083.jpg
# frame_0084.jpg
# frame_0085.jpg
# frame_0086.jpg
# frame_0087.jpg
# frame_0088.jpg
# frame_0089.jpg
# frame_0090.jpg
# frame_0091.jpg
# frame_0092.jpg
# frame_0093.jpg
# frame_0094.jpg
# frame_0095.jpg
# frame_0096.jpg
# frame_0097.jpg
# frame_0098.jpg
# frame_0099.jpg
# frame_0100.jpg
# frame_0101.jpg
# frame_0102.jpg
# frame_0103.jpg
# frame_0104.jpg
# frame_0105.jpg
# frame_0106.jpg
# frame_0107.jpg
# frame_0108.jpg
# frame_0109.jpg
# frame_0110.jpg
# frame_0111.jpg
# frame_0112.jpg
# frame_0113.jpg
# frame_0114.jpg
# frame_0115.jpg
# frame_0116.jpg
# frame_0117.jpg
# frame_0118.jpg
# frame_0119.jpg

# %%
import matplotlib.pyplot as plt
from PIL import Image


fig,axes=plt.subplots(4,5,figsize=(15,10))

for ax ,frame_path in zip(axes.flat,frames):
    image=Image.open(frame_path)

    ax.imshow(image)
    ax.set_title(frame_path.stem)
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
from PIL import Image

for frame_path in frames[:3]:
    image = Image.open(frame_path)

    print(
        frame_path.name,
        "size =", image.size,
        "mode =", image.mode
    )
# Out:
# frame_0000.jpg size = (408, 720) mode = RGB
# frame_0001.jpg size = (408, 720) mode = RGB
# frame_0002.jpg size = (408, 720) mode = RGB

# %% [markdown]
# ## **Working with Dust3R Model :**

# %%
# !git clone --recursive https://github.com/naver/dust3r

# %%
# # * downloading the Model :

from src.dust3r.model_manager import get_checkpoint

CHECKPOINT_DIR = (
    PROJECT_ROOT
    / "dust3r"
    / "checkpoints"
)

CHECKPOINT_DIR
# Out:
# WindowsPath('d:/3D Reconstruction/dust3r/checkpoints')

# %%
checkpoint_path = get_checkpoint(
    model_name="512_dpt",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth

# %%
checkpoint_path = get_checkpoint(
    model_name="512_linear",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_linear.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_linear.pth

# %%
checkpoint_path = get_checkpoint(
    model_name="224_linear",
    checkpoint_dir=CHECKPOINT_DIR,
)

print(checkpoint_path)
# Out:
# Checkpoint already exists:
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_224_linear.pth
# d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_224_linear.pth

# %% [markdown]
# ## **Loading the Model + Inference Test :**

# %%
import dust3r

print(dust3r.__file__)
# Out:
# d:\3D Reconstruction\dust3r\dust3r\__init__.py

# %%
from pathlib import Path

from src.dust3r.reconstruction import reconstruct



frames_dir = (
    PROJECT_ROOT
    /"src"
    / "results"
    / "dust3r"
    / f"exp_{experiment}_baseline"
    / "dataset"
    / "frames"
)

checkpoint_path = (
    PROJECT_ROOT
    / "dust3r"
    / "checkpoints"
    / "DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth"
)

output_dir = (
    PROJECT_ROOT
    /"src"
    / "results"
    / "dust3r"
    / f"exp_{experiment}_baseline"
    / "results"
)
# Out:
# d:\3D Reconstruction\dust3r\dust3r\cloud_opt\base_opt.py:275: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)

# %%
print(frames_dir)
print(frames_dir.exists())
print(list(frames_dir.glob("*"))[:10])
# Out:
# d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames
# True
# [WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0000.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0001.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0002.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0003.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0004.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0005.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0006.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0007.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0008.jpg'), WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/dataset/frames/frame_0009.jpg')]

# %%
reconstruct(
    frames_dir=frames_dir,
    checkpoint_path=checkpoint_path,
    output_dir=output_dir,
)
# Out:
# Device: cuda
# Frames: d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames
# Checkpoint: d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# Warning, cannot find cuda-compiled version of RoPE2D, using a slow pytorch version instead
#
# Loading DUSt3R model...
# ... loading model from d:\3D Reconstruction\dust3r\checkpoints\DUSt3R_ViTLarge_BaseDecoder_512_dpt.pth
# instantiating : AsymmetricCroCo3DStereo(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100', patch_embed_cls='PatchEmbedDust3R', img_size=(512, 512), head_type='dpt', output_mode='pts3d', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), landscape_only=False)
# <All keys matched successfully>
# Model loaded.
#
# Loading 120 images...
# >> Loading a list of 120 images
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0000.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0001.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0002.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0003.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0004.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0005.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0006.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0007.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0008.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0009.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0010.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0011.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0012.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0013.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0014.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0015.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0016.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0017.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0018.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0019.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0020.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0021.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0022.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0023.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0024.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0025.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0026.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0027.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0028.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0029.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0030.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0031.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0032.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0033.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0034.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0035.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0036.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0037.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0038.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0039.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0040.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0041.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0042.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0043.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0044.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0045.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0046.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0047.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0048.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0049.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0050.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0051.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0052.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0053.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0054.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0055.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0056.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0057.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0058.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0059.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0060.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0061.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0062.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0063.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0064.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0065.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0066.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0067.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0068.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0069.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0070.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0071.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0072.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0073.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0074.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0075.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0076.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0077.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0078.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0079.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0080.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0081.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0082.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0083.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0084.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0085.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0086.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0087.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0088.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0089.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0090.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0091.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0092.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0093.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0094.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0095.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0096.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0097.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0098.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0099.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0100.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0101.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0102.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0103.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0104.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0105.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0106.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0107.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0108.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0109.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0110.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0111.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0112.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0113.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0114.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0115.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0116.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0117.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0118.jpg with resolution 408x720 --> 288x512
#  - adding d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\dataset\frames\frame_0119.jpg with resolution 408x720 --> 288x512
#  (Found 120 images)
# Images loaded.
#
# Creating image pairs...
# Number of pairs: 480
#
# Running DUSt3R inference...
# >> Inference with model on 480 image pairs
#   0%|          | 0/480 [00:00<?, ?it/s]d:\3D Reconstruction\dust3r\dust3r\inference.py:44: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=bool(use_amp)):
# d:\3D Reconstruction\dust3r\dust3r\model.py:264: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# d:\3D Reconstruction\dust3r\dust3r\inference.py:48: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 100%|██████████| 480/480 [02:10<00:00,  3.68it/s]
# Inference completed.
#
# Running global alignment...
#  init edge (102*,100*) score=np.float64(197.4346466064453)
#  init edge (102,104*) score=np.float64(190.650634765625)
#  init edge (103*,104) score=np.float64(174.93331909179688)
#  init edge (104,106*) score=np.float64(169.14401245117188)
#  init edge (98*,100) score=np.float64(155.73541259765625)
#  init edge (103,105*) score=np.float64(148.33868408203125)
#  init edge (106,108*) score=np.float64(123.8609619140625)
#  init edge (98,96*) score=np.float64(114.83982849121094)
#  init edge (105,107*) score=np.float64(103.05359649658203)
#  init edge (107,109*) score=np.float64(101.34636688232422)
#  init edge (108,110*) score=np.float64(91.39432525634766)
#  init edge (112*,110) score=np.float64(81.78014373779297)
#  init edge (94*,96) score=np.float64(76.55879974365234)
#  init edge (114*,112) score=np.float64(50.144371032714844)
#  init edge (101*,103) score=np.float64(180.38995361328125)
#  init edge (99*,101) score=np.float64(166.76573181152344)
#  init edge (97*,99) score=np.float64(152.37982177734375)
#  init edge (109,111*) score=np.float64(102.37592315673828)
#  init edge (95*,97) score=np.float64(93.67594146728516)
#  init edge (113*,111) score=np.float64(77.78568267822266)
#  init edge (93*,95) score=np.float64(63.86641311645508)
#  init edge (93,92*) score=np.float64(61.55126953125)
#  init edge (116*,114) score=np.float64(51.555179595947266)
#  init edge (117*,116) score=np.float64(42.55231475830078)
#  init edge (119*,117) score=np.float64(27.441024780273438)
#  init edge (90*,92) score=np.float64(69.46432495117188)
#  init edge (93,91*) score=np.float64(66.21061706542969)
#  init edge (90,88*) score=np.float64(56.10031509399414)
#  init edge (89*,91) score=np.float64(54.548309326171875)
#  init edge (117,118*) score=np.float64(53.64998245239258)
#  init edge (117,115*) score=np.float64(52.79570388793945)
#  init edge (88,86*) score=np.float64(61.4012451171875)
#  init edge (85*,86) score=np.float64(50.919464111328125)
#  init edge (85,83*) score=np.float64(69.5766372680664)
#  init edge (87*,85) score=np.float64(64.34471893310547)
#  init edge (84*,86) score=np.float64(63.36777877807617)
#  init edge (83,81*) score=np.float64(53.295555114746094)
#  init edge (79*,81) score=np.float64(40.46586608886719)
#  init edge (77*,79) score=np.float64(32.31144714355469)
#  init edge (77,75*) score=np.float64(17.166439056396484)
#  init edge (84,82*) score=np.float64(64.08871459960938)
#  init edge (80*,82) score=np.float64(42.21327590942383)
#  init edge (78*,80) score=np.float64(38.980064392089844)
#  init edge (76*,78) score=np.float64(25.335195541381836)
#  init edge (73*,75) score=np.float64(19.56939125061035)
#  init edge (72*,73) score=np.float64(27.458040237426758)
#  init edge (72,74*) score=np.float64(25.63897705078125)
#  init edge (70*,72) score=np.float64(39.28680419921875)
#  init edge (71*,70) score=np.float64(28.329790115356445)
#  init edge (68*,70) score=np.float64(41.36318588256836)
#  init edge (66*,68) score=np.float64(51.757503509521484)
#  init edge (64*,66) score=np.float64(63.532135009765625)
#  init edge (64,65*) score=np.float64(58.9868278503418)
#  init edge (66,67*) score=np.float64(57.75065231323242)
#  init edge (64,63*) score=np.float64(54.39562225341797)
#  init edge (64,62*) score=np.float64(49.94104766845703)
#  init edge (67,69*) score=np.float64(32.777061462402344)
#  init edge (63,61*) score=np.float64(55.06537628173828)
#  init edge (61,60*) score=np.float64(56.30936050415039)
#  init edge (60,58*) score=np.float64(70.38298034667969)
#  init edge (57*,58) score=np.float64(66.77589416503906)
#  init edge (60,59*) score=np.float64(63.43427658081055)
#  init edge (57,55*) score=np.float64(61.630489349365234)
#  init edge (57,56*) score=np.float64(58.45328140258789)
#  init edge (56,54*) score=np.float64(35.841148376464844)
#  init edge (55,53*) score=np.float64(33.8018684387207)
#  init edge (54,52*) score=np.float64(24.819272994995117)
#  init edge (52,50*) score=np.float64(15.469346046447754)
#  init edge (51*,52) score=np.float64(14.68200969696045)
#  init edge (50,48*) score=np.float64(16.709320068359375)
#  init edge (48,46*) score=np.float64(27.853057861328125)
#  init edge (47*,48) score=np.float64(26.93926429748535)
#  init edge (47,49*) score=np.float64(23.992023468017578)
#  init edge (47,45*) score=np.float64(28.762834548950195)
#  init edge (45,43*) score=np.float64(31.301158905029297)
#  init edge (43,41*) score=np.float64(40.8858528137207)
#  init edge (41,40*) score=np.float64(35.887290954589844)
#  init edge (41,39*) score=np.float64(35.03075408935547)
#  init edge (40,38*) score=np.float64(33.01148223876953)
#  init edge (43,44*) score=np.float64(31.808046340942383)
#  init edge (38,36*) score=np.float64(29.55780792236328)
#  init edge (36,34*) score=np.float64(58.17329025268555)
#  init edge (35*,34) score=np.float64(57.491111755371094)
#  init edge (37*,35) score=np.float64(45.903778076171875)
#  init edge (42*,40) score=np.float64(38.9503288269043)
#  init edge (34,32*) score=np.float64(70.60616302490234)
#  init edge (33*,32) score=np.float64(69.45436096191406)
#  init edge (32,30*) score=np.float64(92.71390533447266)
#  init edge (30,29*) score=np.float64(89.8052978515625)
#  init edge (30,28*) score=np.float64(89.54417419433594)
#  init edge (28,26*) score=np.float64(84.64598846435547)
#  init edge (31*,30) score=np.float64(83.16802215576172)
#  init edge (26,24*) score=np.float64(103.35482025146484)
#  init edge (29,27*) score=np.float64(94.00924682617188)
#  init edge (24,22*) score=np.float64(85.70008087158203)
#  init edge (25*,27) score=np.float64(82.42354583740234)
#  init edge (21*,22) score=np.float64(79.87095642089844)
#  init edge (25,23*) score=np.float64(77.32939910888672)
#  init edge (21,19*) score=np.float64(90.72581481933594)
#  init edge (18*,19) score=np.float64(88.62781524658203)
#  init edge (18,16*) score=np.float64(80.29202270507812)
#  init edge (21,20*) score=np.float64(80.11984252929688)
#  init edge (18,17*) score=np.float64(75.80107116699219)
#  init edge (17,15*) score=np.float64(63.56884002685547)
#  init edge (16,14*) score=np.float64(59.91596603393555)
#  init edge (14,12*) score=np.float64(55.6204833984375)
#  init edge (12,13*) score=np.float64(49.20378875732422)
#  init edge (10*,12) score=np.float64(34.80480194091797)
#  init edge (13,11*) score=np.float64(59.35598373413086)
#  init edge (9*,11) score=np.float64(44.569923400878906)
#  init edge (9,7*) score=np.float64(36.63850402832031)
#  init edge (6*,7) score=np.float64(29.150747299194336)
#  init edge (8*,6) score=np.float64(29.09600067138672)
#  init edge (4*,6) score=np.float64(27.480310440063477)
#  init edge (5*,7) score=np.float64(27.361562728881836)
#  init edge (2*,4) score=np.float64(28.541730880737305)
#  init edge (2,3*) score=np.float64(24.855751037597656)
#  init edge (1*,2) score=np.float64(16.341901779174805)
#  init edge (1,0*) score=np.float64(21.186248779296875)
#  init loss = 0.014814997091889381
# Global alignement - optimizing for:
# ['pw_poses', 'im_depthmaps', 'im_poses', 'im_focals']
# 100%|██████████| 300/300 [1:24:26<00:00, 16.89s/it, lr=1.27413e-06 loss=0.00480895]
# Global alignment completed.
# Final loss: 0.004808949306607246
#
# Extracting point cloud...
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Point count: 16516328
#
# Point cloud saved:
# d:\3D Reconstruction\src\results\dust3r\exp_04_baseline\results\point_cloud.ply
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/results/point_cloud.ply')

# %%
output_dir
# Out:
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/results')

# %%
point_cloud=output_dir/"point_cloud.ply"
point_cloud
# Out:
# WindowsPath('d:/3D Reconstruction/src/results/dust3r/exp_04_baseline/results/point_cloud.ply')

# %%
import open3d as o3d

point_cloud=output_dir/"point_cloud.ply"


dense_pcd = o3d.io.read_point_cloud(
    point_cloud
)


print(dense_pcd)
print("Dense points:", len(dense_pcd.points))
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# PointCloud with 16516328 points.
# Dense points: 16516328

# %%
o3d.visualization.draw_geometries([dense_pcd])
